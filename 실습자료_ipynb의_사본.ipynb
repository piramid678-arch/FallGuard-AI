# %% [markdown]
# <a href="https://colab.research.google.com/github/piramid678-arch/FallGuard-AI/blob/master/%EC%8B%A4%EC%8A%B5%EC%9E%90%EB%A3%8C_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U qwen-tts soundfile
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 118.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.3/32.3 MB 72.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 99.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 47.4 MB/s eta 0:00:00
# ...

# %%
import torch

assert torch.cuda.is_available(), "GPU가 꺼져있는데요?"

dtype = torch.bfloat16 if torch.cuda.is_bf16_supported() else torch.float16

print("GPU 준비 완료")
# Out:
# GPU 준비 완료

# %%
from qwen_tts import Qwen3TTSModel

model=Qwen3TTSModel.from_pretrained("Qwen/Qwen3-TTS-12Hz-0.6B-Base",device_map="cuda:0", dtype=dtype,)

print("모델 로드 완료!")
# Out:
# WARNING:sox:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
# ********
# ...
# ********
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.83G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/245 [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# ...

# %%
from google.colab import files

print("당신의 목소리를 3초 이상 녹음해서 올리세요!")

uploaded= files.upload()

내목소리 = list(uploaded.keys())[0]

print("내 목소리 업로드 완료하였습니다!")
# Out:
# 당신의 목소리를 3초 이상 녹음해서 올리세요!
#      <input type="file" id="files-e991d650-c665-4447-a9f7-7d89eff96914" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e991d650-c665-4447-a9f7-7d89eff96914">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import soundfile as sf
import importlib
importlib.reload(sf)
from IPython.display import Audio, display

녹음내용="안녕하세요 저는 제이라고 합니다. 저는 인공지능을 교육하고 있습니다. 저는 인공지능을 너무너무 사랑합니다."
생성내용="안녕. 저는 콩콩이라고 합니다. 저는 수학을 좋아합니다. 컴퓨터는 싫어합니다"

wavs, sr = model.generate_voice_clone( text = 생성내용,
                                      language="Korean",
                                       ref_audio=내목소리,
                                       ref_text=녹음내용,
                                       )
sf.write("내목소리.wav", wavs[0], sr)
print("생성완료!!")

display(Audio("내목소리.wav"))
# Out:
# /usr/local/lib/python3.12/dist-packages/qwen_tts/inference/qwen3_tts_model.py:218: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(x, sr=None, mono=True)
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# 생성완료!!
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
생성내용='''남들 다 하는 평범한 길 대신, 내 이름 석 자를 건 새로운 도전을 시작하려고 합니다.

안녕하세요, 마효권입니다."

"유튜브 크리에이터, 그리고 1인 기업가.

누군가는 '지금 시작하기엔 늦지 않았냐'고 묻지만, 저는 매일 생각했습니다.

'진짜 내 세상은 내가 직접 만들어가야 하는 게 아닐까?' 하고요."

"거창한 성공 스토리로 포장하지 않겠습니다.

밑바닥부터 하나씩 부딪히고, 배우고, 성장하는 저의 진짜 1인 사업 도전기를 날것 그대로 보여드리겠습니다.

넘어지는 순간조차 저에게는 가장 확실한 배움의 콘텐츠가 될 테니까요."


"망설임 대신 행동으로, 말보다는 결과로 증명해 보이겠습니다.

마효권의 첫걸음, 지금 시작합니다.

구독과 응원으로 이 뜨거운 여정을 함께 지켜봐 주세요. 감사합니다!'''

wavs, sr = model.generate_voice_clone( text = 생성내용,
                                      language="Korean",
                                       ref_audio=내목소리,
                                       ref_text=녹음내용,
                                       )
sf.write("내목소리.wav", wavs[0], sr)
print("생성완료!!")

display(Audio("내목소리.wav"))
# Out:
# /usr/local/lib/python3.12/dist-packages/qwen_tts/inference/qwen3_tts_model.py:218: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(x, sr=None, mono=True)
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_576/1412139956.py in <cell line: 0>()
#      22 구독과 응원으로 이 뜨거운 여정을 함께 지켜봐 주세요. 감사합니다!'''
#      23
# ---> 24 wavs, sr = model.generate_voice_clone( text = 생성내용,
#      25                                       language="Korean",
# ...
